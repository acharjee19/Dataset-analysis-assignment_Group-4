# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio

from datetime import datetime

# %%
weather=pd.read_csv('weatherHistory.csv')

# %%
weather.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
new_column_names={'Formatted Date':'Date','Temperature (C)':'Temperature','Apparent Temperature (C)':'Apparent Temperature','Wind Speed (km/h)':'Wind Speed','Visibility (km)':'Visibility','Pressure (millibars)':'Pressure'}
weather.rename(columns=new_column_names,inplace=True)

# %%
weather
# Out:
#                                 Date        Summary Precip Type  Temperature  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# ...                              ...            ...         ...          ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
# Date                      96453 non-null object
# Summary                   96453 non-null object
# Precip Type               95936 non-null object
# Temperature               96453 non-null float64
# Apparent Temperature      96453 non-null float64
# Humidity                  96453 non-null float64
# Wind Speed                96453 non-null float64
# Wind Bearing (degrees)    96453 non-null float64
# Visibility                96453 non-null float64
# Loud Cover                96453 non-null float64
# Pressure                  96453 non-null float64
# Daily Summary             96453 non-null object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
weather.describe()
# Out:
#         Temperature  Apparent Temperature      Humidity    Wind Speed  \
# count  96453.000000          96453.000000  96453.000000  96453.000000
# mean      11.932678             10.855029      0.734899     10.810640
# std        9.551546             10.696847      0.195473      6.913571
# min      -21.822222            -27.716667      0.000000      0.000000
# 25%        4.688889              2.311111      0.600000      5.828200
# 50%       12.000000             12.000000      0.780000      9.965900
# 75%       18.838889             18.838889      0.890000     14.135800
# max       39.905556             39.344444      1.000000     63.852600
#
#        Wind Bearing (degrees)    Visibility  Loud Cover      Pressure
# count            96453.000000  96453.000000     96453.0  96453.000000
# mean               187.509232     10.347325         0.0   1003.235956
# std                107.383428      4.192123         0.0    116.969906
# ...

# %%
weather['Summary'].value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Windy and Mostly Cloudy                   35
# Breezy and Foggy                          35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
weather['Temperature'].max()
# Out:
# 39.90555555555555

# %%
weather.sort_values('Temperature', ascending=False).head(10)
# Out:
#                                 Date        Summary Precip Type  Temperature  \
# 12759  2007-07-22 15:00:00.000 +0200          Clear        rain    39.905556
# 12737  2007-07-21 17:00:00.000 +0200  Partly Cloudy        rain    39.588889
# 12664  2007-07-19 16:00:00.000 +0200  Partly Cloudy        rain    38.983333
# 12712  2007-07-20 16:00:00.000 +0200  Partly Cloudy        rain    38.983333
# 12711  2007-07-20 15:00:00.000 +0200  Partly Cloudy        rain    38.983333
# 12735  2007-07-21 15:00:00.000 +0200  Partly Cloudy        rain    38.866667
# 53727  2012-08-24 15:00:00.000 +0200  Partly Cloudy        rain    38.861111
# 12736  2007-07-21 16:00:00.000 +0200  Partly Cloudy        rain    38.844444
# 12760  2007-07-22 16:00:00.000 +0200  Partly Cloudy        rain    38.838889
# 53728  2012-08-24 16:00:00.000 +0200  Partly Cloudy        rain    38.838889
#
#        Apparent Temperature  Humidity  Wind Speed  Wind Bearing (degrees)  \
# ...

# %% [markdown]
# #### unique Wind speed values in the date

# %%
weather['Wind Speed'].nunique()
# Out:
# 2484

# %%
weather['Wind Speed'].max()
# Out:
# 63.8526

# %% [markdown]
# #### weather exactly clear

# %%
weather.Summary.value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Windy and Mostly Cloudy                   35
# Breezy and Foggy                          35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
weather[weather.Summary =='Clear']
# Out:
#                                 Date Summary Precip Type  Temperature  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain     8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain    12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain     9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain     9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain    12.494444
# ...                              ...     ...         ...          ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain    15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain    15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain    15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain    13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain    16.072222
#
#        Apparent Temperature  Humidity  Wind Speed  Wind Bearing (degrees)  \
# ...

# %% [markdown]
# #### weather exactly Dangerously Windy and Partly Cloudy

# %%
weather[weather.Summary =='Dangerously Windy and Partly Cloudy']
# Out:
#                                 Date                              Summary  \
# 12181  2007-01-29 13:00:00.000 +0100  Dangerously Windy and Partly Cloudy
#
#       Precip Type  Temperature  Apparent Temperature  Humidity  Wind Speed  \
# 12181        rain     8.944444              3.483333      0.49     63.8526
#
#        Wind Bearing (degrees)  Visibility  Loud Cover  Pressure  \
# 12181                   307.0     11.4471         0.0   1009.05
#
#                                            Daily Summary
# 12181  Mostly cloudy throughout the day and windy sta...

# %% [markdown]
# ### Standard Deviation in the data

# %%
weather.std()
# Out:
# Temperature                 9.551546
# Apparent Temperature       10.696847
# Humidity                    0.195473
# Wind Speed                  6.913571
# Wind Bearing (degrees)    107.383428
# Visibility                  4.192123
# Loud Cover                  0.000000
# Pressure                  116.969906
# dtype: float64

# %% [markdown]
# #### all Records for Fog weather

# %%
weather.groupby('Summary').get_group('Foggy')
# Out:
#                                 Date Summary Precip Type  Temperature  \
# 66     2006-04-11 18:00:00.000 +0200   Foggy        rain    10.911111
# 67     2006-04-11 19:00:00.000 +0200   Foggy        rain     8.800000
# 72     2006-04-12 00:00:00.000 +0200   Foggy        rain     8.200000
# 73     2006-04-12 01:00:00.000 +0200   Foggy        rain     8.177778
# 126    2006-04-14 06:00:00.000 +0200   Foggy        rain     5.211111
# ...                              ...     ...         ...          ...
# 95858  2016-09-14 05:00:00.000 +0200   Foggy        rain    13.144444
# 95859  2016-09-14 06:00:00.000 +0200   Foggy        rain    13.822222
# 95860  2016-09-14 07:00:00.000 +0200   Foggy        rain    13.872222
# 95907  2016-09-16 06:00:00.000 +0200   Foggy        rain    14.905556
# 96228  2016-09-28 15:00:00.000 +0200   Foggy        rain    22.800000
#
#        Apparent Temperature  Humidity  Wind Speed  Wind Bearing (degrees)  \
# ...

# %% [markdown]
# #### Mean value of each column against each daily summary

# %%
weather.groupby('Daily Summary').mean()
# Out:
#                                                  Temperature  \
# Daily Summary
# Breezy and foggy starting in the evening.           4.523843
# Breezy and foggy until morning.                    -4.869213
# Breezy and mostly cloudy overnight.                 3.755787
# Breezy and partly cloudy in the afternoon.         28.097917
# Breezy in the morning and foggy in the evening.     0.743750
# ...                                                      ...
# Partly cloudy until night.                         17.675495
# Rain throughout the day.                           10.128241
# Rain until afternoon.                              11.701157
# Rain until morning.                                 9.304630
# Windy in the afternoon.                             4.538889
#
#                                                  Apparent Temperature  \
# Daily Summary
# Breezy and foggy starting in the evening.                    0.485880
# ...

# %% [markdown]
# #### Minimum & Maximum value of each column against each daily summary

# %%
weather.groupby('Daily Summary').max()
# Out:
#                                                                           Date  \
# Daily Summary
# Breezy and foggy starting in the evening.        2013-03-14 23:00:00.000 +0100
# Breezy and foggy until morning.                  2012-12-09 23:00:00.000 +0100
# Breezy and mostly cloudy overnight.              2007-11-11 23:00:00.000 +0100
# Breezy and partly cloudy in the afternoon.       2007-07-24 23:00:00.000 +0200
# Breezy in the morning and foggy in the evening.  2015-02-06 23:00:00.000 +0100
# ...                                                                        ...
# Partly cloudy until night.                       2016-10-09 23:00:00.000 +0200
# Rain throughout the day.                         2016-10-21 23:00:00.000 +0200
# Rain until afternoon.                            2016-10-26 23:00:00.000 +0200
# Rain until morning.                              2016-10-22 23:00:00.000 +0200
# Windy in the afternoon.                          2014-12-21 23:00:00.000 +0100
#
# ...

# %%
weather.groupby('Daily Summary').min()
# Out:
#                                                                           Date  \
# Daily Summary
# Breezy and foggy starting in the evening.        2013-03-14 00:00:00.000 +0100
# Breezy and foggy until morning.                  2012-12-09 00:00:00.000 +0100
# Breezy and mostly cloudy overnight.              2007-11-11 00:00:00.000 +0100
# Breezy and partly cloudy in the afternoon.       2007-07-24 00:00:00.000 +0200
# Breezy in the morning and foggy in the evening.  2015-02-06 00:00:00.000 +0100
# ...                                                                        ...
# Partly cloudy until night.                       2006-02-13 00:00:00.000 +0100
# Rain throughout the day.                         2016-10-21 00:00:00.000 +0200
# Rain until afternoon.                            2016-10-26 00:00:00.000 +0200
# Rain until morning.                              2016-10-22 00:00:00.000 +0200
# Windy in the afternoon.                          2014-12-21 00:00:00.000 +0100
#
# ...

# %%
weather.head(2)
# Out:
#                             Date        Summary Precip Type  Temperature  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
#
#    Apparent Temperature  Humidity  Wind Speed  Wind Bearing (degrees)  \
# 0              7.388889      0.89     14.1197                   251.0
# 1              7.227778      0.86     14.2646                   259.0
#
#    Visibility  Loud Cover  Pressure                      Daily Summary
# 0     15.8263         0.0   1015.13  Partly cloudy throughout the day.
# 1     15.8263         0.0   1015.63  Partly cloudy throughout the day.

# %% [markdown]
# #### Weather is clear and Visibility above 10

# %%
weather[(weather['Summary']=='Clear')| (weather['Visibility']>10.00)]
# Out:
#                                 Date        Summary Precip Type  Temperature  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain     9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain     9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain     9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain     8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain     8.755556
# ...                              ...            ...         ...          ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain    26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain    24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain    22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain    21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain    20.438889
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math
import numpy as np
# %matplotlib inline
sns.set()

# %%
sns.barplot(weather['Humidity'],weather['Temperature'])

# %%
sns.distplot(weather['Temperature'])

# %%
sns.pairplot(weather[['Temperature','Humidity','Wind Speed']])

# %%
import matplotlib.pyplot as plt
import pandas as pd

fig, ax = plt.subplots()

ax.violinplot(weather["Temperature"], vert=False)


plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.hist(weather['Temperature'])

plt.show()
